# %% [markdown]
# # JavaScript_01 - DOM

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 02. 변수
#
# #### #JavaScript 문법 학습
#
# - EMCAScript 2015(ES6) 이후의 명제를 따름
#
# - 권장 스타일 가이드
#
#     - https://standardjs.com/rules-kokr.html

# %% [markdown]
# ### < 변수 작성 규칙 >
#
# #### #식별자(변수명) 작성 규칙
#
# - 반드시 문자, 달러(```$```) 또는 밑줄(```_```)로 시작한다.
#
# - 대소문자를 구분한다.
#
# - ```예약어```는 사용이 ```불가능```하다.
#
#     - ex) for, if, function 등
#
# #### #식별자(변수명) Naming case
#
# - 카멜 케이스(camelCase)
#     - 변수, 객체, 함수에 사용
#
# - 파스칼 케이스(PascalCase)
#     - 클래스, 생성자에 사용
#
# - 대문자 스네이크 케이스(SNAKE_CASE)
#     - 상수(constants)에 사용

# %% [markdown]
# ---

# %% [markdown]
# ### < 변수 선언 키워드 >
#
# #### #1. let
#
# - *블록 스코프(block scope)를 갖는 지역 변수를 선언
#
# - ```재할당 가능```
#
# - 재선언 불가능
#
# - ES6에서 추가
#
#     ![image.png](attachment:image.png)
#
#     ![image-2.png](attachment:image-2.png)
#
# #### #2. const
#
# - *블록 스코프를 갖는 지역 변수를 선언
#
# - ```재할당 불가능```
#
# - 재선언 불가능
#
# - ES6에서 추가
#
#     ![image-3.png](attachment:image-3.png)
#
#     ![image-4.png](attachment:image-4.png)
#
#     ![image-5.png](attachment:image-5.png)
#
#     ⨳ 선언 시 반드시 초기값 설정 필요
#
# #### *블록 스코프(block scope)
#
# - if, for, 함수 등의 '중괄호(```{}```) 내부'를 가리킴
#
# - 블록 스코프를 가지는 변수는 블록 바깥에서 접근 불가능
#
#     ![image-6.png](attachment:image-6.png)
#
# #### #어떤 변수 선언 키워드를 사용해야 할까?
#
# - ```const```를 기본으로 사용한다.
#
# - 필요한 경우에만 let으로 전환한다.
#
#     - 재할당이 필요한 경우
#
#     - let을 사용하는 것은 해당 변수가 의도적으로 변경될 수 있음을 명확히 나타냄
#
#     - 코드의 유연성을 확보하면서도 const의 장점을 최대한 활용할 수 있음
#
# #### #const를 기본으로 사용해야 하는 이유
#
# - 코드의 의도 명확화
#
#     - 해당 변수가 재할당되지 않을 것임을 명확히 표현
#
#     - 개발자들에게 변수의 용도와 동작을 더 쉽게 이해할 수 있게 해줌
#
# - 버그 예방
#
#     - 의도치 않은 변수 값 변경으로 인한 버그를 예방
#
#     - 큰 규모의 프로젝트나 팀 작업에서 중요

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 03. DOM - The Document Object Model
# : 웹 페이지(Document)를 구조화된 객체로 제공하여 프로그래밍 언어가 페이지 구조에 접근할 수 있는 방법을 제공함
#
#     문서 구조, 스타일, 내용 등을 변경할 수 있도록 함
#
# - 웹 브라우저에서의 JS는 웹 페이지의 ```동적인``` 기능을 구현한다.
#
# #### #JavaScript 실행 환경 종류
#
# 1. HTML script 태그
#
#     ![image.png](attachment:image.png)
#
# 2. js 확장자 파일
#
#     ![image-2.png](attachment:image-2.png)
#
#     ![image-3.png](attachment:image-3.png)
#
# 3. 브라우저 Console(콘솔)
#
#     ![image-4.png](attachment:image-4.png)
#
# #### #DOM API
#
# - 다른 프로그래밍 언어가 웹 페이지에 접근 및 조작할 수 있도록 페이지 요소들을 객체 형태로 제공하며 이에 따른 메서드 또한 제공한다.
#
#     ![image-5.png](attachment:image-5.png)
#
# #### #DOM 특징
#
# - DOM에서 모든 요소, 속성, 텍스트는 하나의 객체
#
# - 모두 document 객체의 하위 객체로 구성된다.
#
#     ![image-6.png](attachment:image-6.png)
#
# #### #DOM tree
#
# - 브라우저는 HTML 문서를 해석하여 DOM tree라는 객체 트리로 구조화
#
#     - 객체 간 상속 구조가 존재함
#
# ![image-7.png](attachment:image-7.png)
#
# ### #DOM 핵심
# : 문서의 요소들을 객체로 제공하여 다른 프로그래밍 언어에서 접근하고 조작할 수 있는 방법을 제공하는 API

# %% [markdown]
# ---

# %% [markdown]
# ### < document 객체 >
#
# - 웹 페이지 객체
#
# - DOM Tree의 진입점
#
# - 페이지를 구성하는 모든 객체 요소를 포함
#
#     ![image.png](attachment:image.png)
#
# - 예시
#
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 04. DOM 선택
#
# ### #DOM 조작 시 기억해야 할 것
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### < 선택 메서드 >
#
# ![image.png](attachment:image.png)
#
# ```document.querySelector(selector)```
#
# - 제공한 선택자와 일치하는 element 한 개 선택
#
#     → 제공한 선택자를 만족하는 첫 번째 element 객체를 반환 (없으면 null 반환)
#
# ```document.querySelectorAll(selector)```
#
# - 제공한 선택자와 일치하는 여러 element를 선택
#
#     → 제공한 선택자를 만족하는 NodeList를 반환
#
# #### #DOM 선택 실습
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 05. DOM 조작
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### < 속성 조작 > - 클래스 속성 조작
#
# ![image.png](attachment:image.png)
#
# #### 1. classList 메서드
#
# ![image-2.png](attachment:image-2.png)
#
# - 실습
#
#     ![image-3.png](attachment:image-3.png)
#
#     ![image-4.png](attachment:image-4.png)
#
# - add() 와 remove() 메서드를 사용해 지정한 클래스 값을 추가 혹은 제거
#
#     ![image-5.png](attachment:image-5.png)
#
# #### 2. 일반 속성 조작 메서드
#
# ![image-6.png](attachment:image-6.png)
#
# - 실습
#
#     ![image-8.png](attachment:image-8.png)
#
#     ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ---

# %% [markdown]
# ### < HTML 콘텐츠 조작 >
#
# ![image.png](attachment:image.png)
#
# - 실습
#
#     ![image-2.png](attachment:image-2.png)
#
#     ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ---

# %% [markdown]
# ### < DOM 요소 조작 >
#
# ![image.png](attachment:image.png)
#
# - 실습
#
#     ![image-2.png](attachment:image-2.png)
#
#     ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ---

# %% [markdown]
# ### < style 조작 >
#
# ![image.png](attachment:image.png)
#
# - 실습
#
#     ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 참고

# %% [markdown]
# ### < DOM 속성 확인 TIP >
#
# - 개발자도구 → Elements → Properties
#
# - 선택한 해당 요소의 모든 DOM 속성 확인 가능

# %% [markdown]
# ### < 용어 정리 >
#
# #### #Node
#
# - DOM의 기본 구성 단위
#
# - DOM Tree의 각 부분은 Node라는 객체로 표현됨
#
#     - Document Node: HTML ```문서 전체```를 나타내는 노드
#
#     - Element Node: HTML ```요소```를 나타내는 노드 ex)``` <p> ```
#
#     - Text Node: HTML ```텍스트``` (Element Node 내의 텍스트 컨텐츠를 나타냄)
#
#     - Attribute Node: HTML 요소의 ```속성```을 나타내는 노드
#
# #### #NodeList
#
# - DOM 메서드를 사용해 선택한 Node의 목록
#
# - 배열과 유사한 구조를 가짐
#
# - Index로만 각 항목에 접근이 가능하다
#
# - JS의 배열 메서드를 사용 가능하다
#
# - ```querySelectorAll()```에 의해 반환되는 NodeList는 DOM의 변경사항을 실시간으로 반영하지 않는다
#
#     - DOM이 나중에 변경되더라도 이전에 이미 선택한 NodeList 값은 변하지 않는다.
#
# #### #Element
#
# - Node의 하위 유형
#
# - Element는 DOM 트리에서 HTML 요소를 나타내는 특별한 유형의 노드이다.
#
# - 예를 들어, ```<p>, <div>, <span>, <body>``` 등의 HTML 태그들이 Element 노드를 생성
#
# - 노드의 속성과 메서드를 모두 가지고 있으며 추가적으로 ```요소 특화된 기능```을 가지고 있다.
#
#     - ex) className, innerHTML, id
#
# #### #Parsing(파싱) - 구문 분석, 해석
# : 브라우저가 문자열을 해석하여 DOM Tree로 만드는 과정

# %% [markdown]
# ---

# %% [markdown]
# ### < 세미콜론 (semicolon) >
#
# - JS는 문장 마지막 세미콜론(```;```)을 선택적으로 사용이 가능함
#
# - 세미콜론이 없으면 ASI에 의해 자동으로 세미콜론이 삽입됨

# %% [markdown]
# ---

# %% [markdown]
# ### 변수 선언 키워드 - < var >
#
# - ES6 이전에 변수 선언에 사용했던 키워드
#
# - ```재할당 가능```
#
# - *함수 스코프(function scope)를 가짐
#
# - ```호이스팅```되는 특성으로 인해 예기치 못한 문제 발생 가능
#
#     - 선언하기 전 사용할 수 있음
#
# - 변수 선언 시 ```var, const, let``` 키워드 중 하나를 사용하지 않으면 ```자동으로 var``` 선언
#
# #### *함수 스코프(function scope)
#
# - 함수의 중괄호 내부를 가리킴
#
# - 함수 스코프를 가지는 변수는 함수 바깥에서 접근 불가능
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### < 호이스팅 (hoisting) >
#
# - 변수 선언이 끌어올려 지는 현상
#
#     - var로 선언한 변수는 선언 위치와 상관없이 함수 시작 지점,
#     - 전역에서는 코드가 시작될 때 처리됨
#
# - 변수에 무언가를 할당하기 전까진 ```undefined```를 가짐
#
#     ![image-4.png](attachment:image-4.png)
#
#     ![image-2.png](attachment:image-2.png)
#
# - ```let```과```const```로 선언된 변수도 기술적으로는 호이스팅 되지만, 변수가 만들어지는 내부 과정이 다르기 때문에 이 문제를 방지할 수 있음
#
# ![image-3.png](attachment:image-3.png)
