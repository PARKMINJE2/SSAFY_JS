# %% [markdown]
# # JavaScript_03 - 참조 자료형_01 ( 함수 )

# %% [markdown]
# ---
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ``객체의 "주소"가 저장되는 자료형(가변, 주소가 복사)``
#
# ## Function
# : 참조 자료형에 속하며 모든 함수는 Function object

# %% [markdown]
# ### < 함수 정의 >
#
# #### #함수 구조
#
# ![image.png](attachment:image.png)
#
# - function 키워드
#
# - 함수의 이름
#
# - 함수의 매개변수
#
# - 함수의 body를 구성하는 statements
#
# ``return 값이 없다면 undefined를 반환``
#
# #### #함수 정의 2가지 방법
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# #### #함수 선언식 특징
#
# - 호이스팅 됨
#
# - 코드의 ``구조``와 ``가독성`` 면에서는 표현식에 비해 장점이 있음
#
#     ![image-5.png](attachment:image-5.png)
#
# #### #함수 표현식 특징
#
# - 호이스팅 안 됨
#
#     - 변수 선언만 호이스팅 되고 함수 할당은 실행 시점에 이루어짐
#
# - 함수 이름이 없는 '`익명 함수`'를 사용할 수 있음
#
#     ![image-6.png](attachment:image-6.png)
#
# #### ⨳함수 표현식 사용을 권장하는 이유
#
# - 예측 가능성
#
#     - 호이스팅의 영향을 받지 않아 코드의 실행 흐름을 더 명확하게 예측할 수 있음
#
# - 유연성
#
#     - 변수에 할당되므로 함수를 값으로 다루기 쉬움
#
# - 스코프 관리
#
#     - 블록 스코프를 가지는 let이나 const와 함께 사용하여 더 엄격한 스코프 관리가 가능

# %% [markdown]
# ---

# %% [markdown]
# ### < 매개변수 >
#
# #### #매개변수 정의 방법
#
# 1. 기본 함수 매개변수 (Default function parameter)
#
#     - 전달하는 인자가 없거나 undefined가 전달될 경우 이름 붙은 매개변수를 기본값으로 초기화
#
#         ![image.png](attachment:image.png)
#
# 2. 나머지 매개변수
#
#     - 임의의 수의 인자를 `배열`로 허용하여 가변 인자를 나타내는 방법
#
#     - 작성 규칙
#
#         - 함수 정의 시 나머지 매개변수는 하나만 작성할 수 있음
#
#         - 나머지 매개변수는 함수 정의에서 매개변수 마지막에 위치해야 함
#
#         ![image-2.png](attachment:image-2.png)
#
# #### #매개변수와 인자 개수가 불일치 할 때
#
# 01. 매개변수 개수 `>` 인자 개수
#
# - 누락된 인자는 undefined로 할당
#
#     ![image-3.png](attachment:image-3.png)
#
# 02.  매개변수 개수 `<` 인자 개수
#
# - 초과 입력한 인자는 사용하지 않음 (입력 순서대로 출력)
#
#     ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ---

# %% [markdown]
# ### < Spread syntax >
#
# ![image.png](attachment:image.png)
#
# #### #전개 구문
#
# - 배열이나 문자열과 같이 반복 가능한 항목을 펼치는 것 (확장, 전개)
#
# - 전개 대상에 따라 역할이 다름
#
#     - 배열이나 객체의 요소를 개별적인 값으로 분리하거나,
#
#         다른 배열이나 객체의 요소를 현재 배열이나 객체에 추가하는 등
#
# #### #전개 구문 활용처
#
# 1. 함수와의 사용
#
#     ①. 함수 호출 시 인자 확장
#
#     ![image-2.png](attachment:image-2.png)
#
#     ②. 나머지 매개변수 (압축)
#
#     ![image-3.png](attachment:image-3.png)
#
# 2. 객체와의 사용 (객체 파트에서 진행)
#
# 3. 배열과의 활용 (배열 파트에서 진행)

# %% [markdown]
# ---

# %% [markdown]
# ### < 화살표 함수 표현식 > - Arrow function expressions
# : 함수 표현식의 간결한 표현법
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# #### #화살표 함수 작성 과정
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 참고

# %% [markdown]
# ![image.png](attachment:image.png)
