# %% [markdown]
# # JavaScript_02 - Basic syntax

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 01. 데이터 타입
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# - 원시 자료형 예시
#
#     - 변수에 할당될 때 값이 복사됨
#
#         변수 간에 서로 영향을 ```미치지 않음```
#
#         ![image-3.png](attachment:image-3.png)
#
#         ![image-4.png](attachment:image-4.png)
#
# - 참조 자료형 예시
#
#     - 객체를 생성하면 객체의 메모리 주소를 변수에 할당
#
#         변수 간에 서로 영향을 ```미침```
#
#         ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### < 원시 자료형 >
#
# - 종류
#
#     - Number
#
#     - String
#
#     - null
#
#     - undefined
#
#     - Boolean
#
# #### #Number
# : ```정수 또는 실수형 숫자```를 표현하는 자료형
#
# - 예시
#
#     ![image.png](attachment:image.png)
#
# #### #String
# : ```텍스트 데이터```를 표현하는 자료형
#
# - 예시
#
#     - ```+``` 연산자를 사용해 문자열끼리 결합
#
#     - 뺄셈, 곱셈, 나눗셈 ```불가능```
#
#         ![image-2.png](attachment:image-2.png)
#
# #### *Template literals (템플릿 리터럴)
#
# - 내장된 표현식을 허용하는 문자열 작성 방식
#
# - Backtick(``)을 이용하며, 여러 줄에 걸쳐 문자열을 정의할 수도 있고 JS의 변수를 문자열 안에 바로 연결할 수 있음
#
# - 표현식은 ```$```와 중괄호(```{expression}```) 로 표기
#
# - ES6+ 부터 지원
#
#     ![image-3.png](attachment:image-3.png)
#
# #### #null 과 undefined
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# #### #Boolean
# : true / false
#
# - 조건문 또는 반복문에서 Boolean이 아닌 데이터 타입은 ```자동 형변환``` 규칙에 따라 true 또는 false로 변환됨
#
# #### *자동 형변환
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 02. 연산자

# %% [markdown]
# #### #할당 연산자
#
# ![image.png](attachment:image.png)
#
# #### #증가 & 감소 연산자
#
# ![image-2.png](attachment:image-2.png)
#
# #### #비교 연산자
#
# ![image-3.png](attachment:image-3.png)
#
# #### #동등 연산자 (==)
#
# ![image-7.png](attachment:image-7.png)
#
# #### #일치 연산자 (===)
#
# ![image-5.png](attachment:image-5.png)
#
# #### #논리 연산자
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 03. 조건문

# %% [markdown]
# #### #if
# : 조건 표현식의 결과값을 boolean 타입으로 변환 후 참/거짓을 판단
#
# - 예시
#
#     ![image.png](attachment:image.png)
#
# #### *삼항 연산자
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# - 예시
#
#     - 간단한 조건부 로직을 간결하게 표현할 때 유용
#
#         ```복잡한 로직이나 대다수의 경우에는 가독성이 떨어질 수 있으므로 적절한 상황에서만 사용할 것```
#
#     ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 04. 반복문
#
# - 종류
#
#     - while
#
#     - for
#
#     - for ...in
#
#     - for ...of
#
# ### < while >
# : 조건문이 참이면 문장을 계속해서 수행
#
# ![image.png](attachment:image.png)
#
# - 예시
#
#     ![image-2.png](attachment:image-2.png)
#
# ---
#
# ### < for >
# : 특정한 조건이 거짓으로 판별될 때까지 반복
#
# ![image-3.png](attachment:image-3.png)
#
# - 예시
#
#     ![image-4.png](attachment:image-4.png)
#
# #### #for 동작 원리
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ---

# %% [markdown]
# ### < for ...in >
# : 객체(``{키 : 값}``)의 열거 가능한 ``속성(property)``에 대해 반복
#
# ![image.png](attachment:image.png)
#
# - 예시
#
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ### < for ...of >
# : 반복 가능한 ``객체(배열, 문자열 등)``에 대해 반복
#
# ![image.png](attachment:image.png)
#
# - 예시
#
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ### < for ...in과 for ...of >
#
# #### #for ...in과 for ...of 비교 (배열과 객체)
#
# ![image.png](attachment:image.png)
#
# #### #배열 반복과 for ...in
#
# - 객체 관점에서 배열의 인덱스는 ``정수 이름을 가진 열거 가능한 속성``
#
# - for ...in은 정수가 아닌 이름과 속성을 포함하여 열거 가능한 모든 속성을 반환
#
# - 내부적으로 for ...in은 배열의 반복자가 아닌 ``속성 열거``를 사용하기 때문에 특정 순서에 따라 인덱스를 반환하는 것을 보장할 수 없음
#
# - for ...in은 인덱스의 순서가 중요한 ``배열에서는 사용하지 않음``
#
# - 배열에서는 ``for문, for ...of를 사용``
#
# - 객체 관점에서 배열의 인덱스는 정수 이름을 가진 속성이기 때문에 인덱스가 출력됨 (순서 보장 X)
#
#     ![image-2.png](attachment:image-2.png)
#
# #### #반복문 사용 시 const 사용 여부
#
# - for 문
#
#     ![image-3.png](attachment:image-3.png)
#
# - for ...in, for ...of
#
#     ![image-4.png](attachment:image-4.png)
#
# #### #반복문 종합
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 참고
